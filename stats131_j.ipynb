# %%
import pandas as pd
house = pd.read_csv("kc_house_data.csv")
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.date = pd.to_datetime({'year':house.date.str[:4], 'month':house.date.str[4:6], 'day':house.date.str[6:8]})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-dea89ad044ea> in <module>
# ----> 1 house.date = pd.to_datetime({'year':house.date.str[:4], 'month':house.date.str[4:6], 'day':house.date.str[6:8]})
#       2 house.ix[:, -[0,1,17,18]]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
house.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = round(house.corr(), 2)
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot = True, xticklabels=corr.columns.values, yticklabels=corr.columns.values, cmap="Greens")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(15,10))
with sns.plotting_context("notebook", font_scale=2.5):
    g = sns.pairplot(house[['bathrooms', 'bedrooms', 'sqft_above', 'price', 'grade', 'sqft_living', 'sqft_living15']], hue='bedrooms', palette='tab20', size=6)
g.set(xticklabels=[])
# Out:
# C:\Users\pooki\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\pooki\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\pooki\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\pooki\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\pooki\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %%
len(house.zipcode.unique())
# Out:
# 70

# %%
#import pyzipcode
from pyzipcode import ZipCodeDatabase
zcdb = ZipCodeDatabase()
zipcode = zcdb[house.zipcode]
zipcode.city
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-7f1c11143c83> in <module>
#       1 #import pyzipcode
# ----> 2 from pyzipcode import ZipCodeDatabase
#       3 zcdb = ZipCodeDatabase()
#       4 zipcode = zcdb[house.zipcode]
#       5 zipcode.city
#
# ModuleNotFoundError: No module named 'pyzipcode'

# %%
from uszipcode import SearchEngine
import re
city = [hi]*len(house)
for i in range(len(house)):
    search = SearchEngine(simple_zipcode=True) # set simple_zipcode=False to use rich info database
    zipcode = search.by_zipcode(house.ix[i,16])
    result = re.search("major_city='(.*)', post_", str(zipcode))
    city[i] = result.group(1)
# Out:
# C:\Users\pooki\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
import re

s = 'asdf=5;iwantthis123jasd'
result = re.search("major_city='(.*)', post_", str(zipcode))
print(result.group(1))
print(result.group(1))
# Out:
# Seattle
# Seattle

# %%
house['city'] = city

# %%
house['city'].unique()[0]
# Out:
# 'Seattle'

# %%
house
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3       1.00         1180
# 1      6414100192 2014-12-09   538000.0         3       2.25         2570
# 2      5631500400 2015-02-25   180000.0         2       1.00          770
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 4      1954400510 2015-02-18   510000.0         3       2.00         1680
# 5      7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6      1321400060 2014-06-27   257500.0         3       2.25         1715
# 7      2008000270 2015-01-15   291850.0         3       1.50         1060
# 8      2414600126 2015-04-15   229500.0         3       1.00         1780
# 9      3793500160 2015-03-12   323000.0         3       2.50         1890
# 10     1736800520 2015-04-03   662500.0         3       2.50         3560
# 11     9212900260 2014-05-27   468000.0         2       1.00         1160
# ...

# %%
df1 = house.groupby("city").count()
df2 = house.groupby("city").mean()
df2.id = df1.id
df2.sort_values(by='id')

# Seattle, Renton, Bellevue, Kent, Redmond, Kirkland, Auburn, Sammamish, Federal Way, Issaquah
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# city
# Medina           50  2.160607e+06  4.060000   3.200000  3800.900000
# Fall City        81  5.805268e+05  3.296296   2.163580  2337.469136
# Black Diamond   100  4.236660e+05  3.290000   2.027500  2137.590000
# Vashon          118  4.874796e+05  2.754237   1.900424  1880.271186
# Carnation       124  4.556171e+05  3.000000   2.048387  2117.967742
# Duvall          190  4.247887e+05  3.363158   2.290789  2171.557895
# Bothell         195  4.903515e+05  3.548718   2.278205  2253.097436
# North Bend      221  4.394711e+05  3.230769   2.110860  2063.823529
# Enumclaw        234  3.157093e+05  3.149573   1.910256  1832.324786
# Mercer Island   282  1.194230e+06  4.028369   2.716312  3106.833333
# Kenmore         283  4.624800e+05  3.480565   2.143110  2122.724382
# Snoqualmie      310  5.279612e+05  3.522581   2.545161  2571.322581
# Woodinville     471  6.173845e+05  3.520170   2.336518  2575.715499
# ...

# %%
seattle = house[house['city'] == 'Seattle']
renton = house[house['city'] == 'Renton']
bellevue = house[house['city'] == 'Bellevue']
kent = house[house['city'] == 'Kent']
redmond = house[house['city'] == 'Redmond']
kirkland = house[house['city'] == 'Kirkland']
auburn = house[house['city'] == 'Auburn']
sammamish = house[house['city'] == 'Sammammish']
federal_way = house[house['city'] == 'Federal Way']
issaquah = house[house['city'] == 'Issaquah']

# %%
seattle[seattle.bedrooms == 1].price
select = pd.concat([seattle, renton, bellevue, kent, redmond, kirkland, auburn, sammamish, federal_way, issaquah])

# %%
one = select[select.bedrooms == 1]
two = select[select.bedrooms == 2]
three = select[select.bedrooms == 3]
four = select[select.bedrooms == 4]
five = select[select.bedrooms == 5]

# %%
import seaborn as sns
plt.figure(figsize=(15,10))
sns.set_style("whitegrid")
ax = sns.boxplot(x="city", y="price", data=one, palette="Set3")
# Out:
# (0, 4000000)

# %%
plt.figure(figsize=(15,10))
sns.set_style("whitegrid")
ax = sns.boxplot(x="city", y="price",              
data=two, palette="Set3")

# %%
plt.figure(figsize=(15,10))
sns.set_style("whitegrid")
ax = sns.boxplot(x="city", y="price",              
data=three, palette="Set3")

# %%
plt.figure(figsize=(15,10))
sns.set_style("whitegrid")
ax = sns.boxplot(x="city", y="price",              
data=four, palette="Set3")

# %%
plt.figure(figsize=(15,10))
sns.set_style("whitegrid")
ax = sns.boxplot(x="city", y="price",              
data=five, palette="Set3")

# %%
corr = round(kent.corr(), 2)
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot = True, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show()

# %%
house
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3       1.00         1180
# 1      6414100192 2014-12-09   538000.0         3       2.25         2570
# 2      5631500400 2015-02-25   180000.0         2       1.00          770
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 4      1954400510 2015-02-18   510000.0         3       2.00         1680
# 5      7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6      1321400060 2014-06-27   257500.0         3       2.25         1715
# 7      2008000270 2015-01-15   291850.0         3       1.50         1060
# 8      2414600126 2015-04-15   229500.0         3       1.00         1780
# 9      3793500160 2015-03-12   323000.0         3       2.50         1890
# 10     1736800520 2015-04-03   662500.0         3       2.50         3560
# 11     9212900260 2014-05-27   468000.0         2       1.00         1160
# ...

# %%
corr = round(house.corr(), 2)
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot = True, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
pd.DataFrame(house.price.describe())
# Out:
#               price
# count  2.161300e+04
# mean   5.400881e+05
# std    3.671272e+05
# min    7.500000e+04
# 25%    3.219500e+05
# 50%    4.500000e+05
# 75%    6.450000e+05
# max    7.700000e+06

# %%
plt.figure(figsize=(15,10))
sns.distplot(house['price'], hist=True, kde=False, 
             color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram of House Sales')
plt.xlabel('House Price')
plt.ylabel('Houses')
# Out:
# Text(0, 0.5, 'Houses')
